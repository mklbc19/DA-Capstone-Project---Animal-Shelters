# %% [markdown]
# The following are data dictionaries of the three datasets included in this project.

# %%
import pandas as pd

df1 = pd.read_excel("Louisville-DD.xlsx")
df2 = pd.read_excel("Dallas-DD.xlsx")
df3 = pd.read_excel("Nationwide-DD.xlsx")

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

print("Louisville Data Dictionary:")
display(df1)
# Out:
# Louisville Data Dictionary:
#            Column Data Type  \
# 0          kennel    String
# 1        animalid    String
# 2    jurisdiction    String
# 3          intype    String
# 4       insubtype    String
# 5          indate    String
# 6       surreason    String
# 7         outtype    String
# 8      outsubtype    String
# 9         outdate    String
# 10     animaltype    String
# 11            sex    String
# 12          bites    String
# 13        petsize    String
# 14          color    String
# 15          breed    String
# 16  sourcezipcode    String
# 17       ObjectId   Integer
#
#                                                      Description
# 0                              Kennel ID (unique to each animal)
# 1                              Animal ID (unique to each animal)
# 2                            Area where the dog was received at.
# 3                                                    Intake Type
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 10000)

print("Dallas Data Dictionary:")
display(df2)
# Out:
# Dallas Data Dictionary:
#                     Column Data Type                                               Description
# 0                Animal Id    String                          Unique identifier for the source
# 1              Animal Type    String                           Type of animal (Cat, dog, etc.)
# 2             Animal Breed    String                                              Animal Breed
# 3            Kennel Number    String         Location wher the animal is in the animal shelter
# 4            Kennel Status    String                                      Status of the kennel
# 5          Activity Number    String                          Unique identifier for the source
# 6        Activity Sequence   Integer  Order of Activities for the intake/outtake of the animal
# 7                Source Id    String                          Unique identifier for the source
# 8             Census Tract    String                  Census Tract associated with the animal.
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 10000)

print("Nationwide Data Dictionary:")
display(df3)
# Out:
# Nationwide Data Dictionary:
#                                                Column name Data Type                                                                                Description
# 0                                                    State    String                                                       The state the data is received from.
# 1                                                     Year   Integer                                                        The year the data is received from.
# 2                                            Organizations   Integer                                               The organizations the data is received from.
# 3              Intake - Relinquished By Owner Total-Feline   Integer                                Animal shelter intake counts of cats relinquished by owner.
# ...
